# %% [markdown]
# ## Exploring DataSets Taken From Kaggle

# %%
import pandas as pd
df=pd.read_csv("data/linkedin_ds_jobs.csv")
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 492 entries, 0 to 491
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   description   492 non-null    object
#  1   company_name  492 non-null    object
#  2   job_title     492 non-null    object
#  3   location      492 non-null    object
#  4   time_posted   492 non-null    object
#  5   applicants    492 non-null    object
#  6   type_info     492 non-null    object
#  7   company_info  492 non-null    object
#  8   skills        294 non-null    object
# dtypes: object(9)
# memory usage: 34.7+ KB
# None

# %% [markdown]
# ### We will apply data cleaning techniques here as Skills column has missing values

# %%
df['skills'].fillna("")

# %%
df2=pd.read_csv("data/banking_finance_jobs.csv")
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  99 non-null     int64
#  1   Job         99 non-null     object
#  2   Company     99 non-null     object
#  3   Location    99 non-null     object
#  4   Experience  70 non-null     object
#  5   Pay         13 non-null     object
#  6   Posted on   99 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 5.5+ KB
# None

# %% [markdown]
# ### We will apply data cleaning techniques here as Experience column has missing values

# %%
df3=pd.read_csv('data/pakistan_jobs.csv')
print(df3.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   jobTitle        31 non-null     object
#  1   companyName     31 non-null     object
#  2   postingDate     31 non-null     object
#  3   salaryRange     0 non-null      float64
#  4   industry        0 non-null      float64
#  5   recruiterPhone  1 non-null      float64
#  6   location        30 non-null     object
#  7   jobType         30 non-null     object
#  8   skills          30 non-null     object
#  9   recruiterEmail  28 non-null     object
#  10  url             30 non-null     object
# dtypes: float64(3), object(8)
# memory usage: 2.8+ KB
# None

# %% [markdown]
# ## We found that job_title is common in all while job_description, experience and skills are present in some datasets. So we will normalize data and pick few mandatory features to analyse jobs.
